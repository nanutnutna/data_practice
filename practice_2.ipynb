# %% [markdown]
# <a href="https://colab.research.google.com/github/nanutnutna/data_practice/blob/master/practice_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
url = 'https://covid19.th-stat.com/api/open/cases'
r = requests.get(url)

# %%
for_df = r.json()

# %%
data_use = for_df['Data']

# %%
import pandas as pd

# %%
show_df = pd.DataFrame(data_use)
show_df
# Out:
#               ConfirmDate    No   Age  ...   District     ProvinceEn Detail
# 0     2020-04-27 00:00:00  2924  24.0  ...     อู่ทอง    Suphan Buri   None
# 1     2020-04-27 00:00:00  2931  18.0  ...  บางคอแหลม        Bangkok   None
# 2     2020-04-27 00:00:00  2928  55.0  ...  บันนังสตา           Yala   None
# 3     2020-04-27 00:00:00  2927  54.0  ...  บันนังสตา           Yala   None
# 4     2020-04-27 00:00:00  2923  66.0  ...       ถลาง         Phuket   None
# ...                   ...   ...   ...  ...        ...            ...    ...
# 2926  2020-01-24 00:00:00     5  66.0  ...                Nonthaburi   None
# 2927  2020-01-22 00:00:00     4  68.0  ...                   Bangkok   None
# 2928  2020-01-22 00:00:00     3  73.0  ...      เมือง  Nakhon Pathom   None
# 2929  2020-01-17 00:00:00     2  74.0  ...                   Bangkok   None
# 2930  2020-01-12 00:00:00     1  61.0  ...                   Bangkok   None
#
# [2931 rows x 12 columns]

# %%
  #only_date = [date for date in range(0,len(show_df['ConfirmDate']))] 
only_date = [date.split()[0] for date in show_df['ConfirmDate']]
# Out:
# ['2020-04-27', '2020-04-27', '2020-04-27', '2020-04-27', '2020-04-27', '2020-04-27', '2020-04-27', '2020-04-27', '2020-04-27', '2020-04-26', '2020-04-26', '2020-04-26', '2020-04-26', '2020-04-26', '2020-04-26', '2020-04-26', '2020-04-26', '2020-04-26', '2020-04-26', '2020-04-26', '2020-04-26', '2020-04-26', '2020-04-26', '2020-04-26', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '2020-04-25', '20
# ...

# %%
show_df.dtypes
# Out:
# ConfirmDate     object
# No              object
# Age            float64
# Gender          object
# GenderEn        object
# Nation          object
# NationEn        object
# Province        object
# ProvinceId       int64
# District        object
# ProvinceEn      object
# Detail          object
# dtype: object

# %%
show_df.describe()
# Out:
#                Age   ProvinceId
# count  2931.000000  2931.000000
# mean     38.999454    19.384169
# std      15.791716    23.133678
# min       0.000000     1.000000
# 25%      27.000000     1.000000
# 50%      37.000000     1.000000
# 75%      50.000000    42.000000
# max      99.000000    78.000000

# %%
ready_table = show_df.drop(columns=['ConfirmDate','Detail'])

# %%
ready_table
# Out:
#         No   Age Gender  ... ProvinceId   District     ProvinceEn
# 0     2924  24.0    ชาย  ...         67     อู่ทอง    Suphan Buri
# 1     2931  18.0    ชาย  ...          1  บางคอแหลม        Bangkok
# 2     2928  55.0    ชาย  ...         47  บันนังสตา           Yala
# 3     2927  54.0    ชาย  ...         47  บันนังสตา           Yala
# 4     2923  66.0   หญิง  ...         42       ถลาง         Phuket
# ...    ...   ...    ...  ...        ...        ...            ...
# 2926     5  66.0   หญิง  ...         24                Nonthaburi
# 2927     4  68.0    ชาย  ...          1                   Bangkok
# 2928     3  73.0   หญิง  ...         19      เมือง  Nakhon Pathom
# 2929     2  74.0   หญิง  ...          1                   Bangkok
# 2930     1  61.0   หญิง  ...          1                   Bangkok
#
# [2931 rows x 10 columns]

# %%
ready_table['Date'] = only_date

# %%
ready_table
# Out:
#         No   Age Gender  ...   District     ProvinceEn        Date
# 0     2924  24.0    ชาย  ...     อู่ทอง    Suphan Buri  2020-04-27
# 1     2931  18.0    ชาย  ...  บางคอแหลม        Bangkok  2020-04-27
# 2     2928  55.0    ชาย  ...  บันนังสตา           Yala  2020-04-27
# 3     2927  54.0    ชาย  ...  บันนังสตา           Yala  2020-04-27
# 4     2923  66.0   หญิง  ...       ถลาง         Phuket  2020-04-27
# ...    ...   ...    ...  ...        ...            ...         ...
# 2926     5  66.0   หญิง  ...                Nonthaburi  2020-01-24
# 2927     4  68.0    ชาย  ...                   Bangkok  2020-01-22
# 2928     3  73.0   หญิง  ...      เมือง  Nakhon Pathom  2020-01-22
# 2929     2  74.0   หญิง  ...                   Bangkok  2020-01-17
# 2930     1  61.0   หญิง  ...                   Bangkok  2020-01-12
#
# [2931 rows x 11 columns]

# %%
ready_table.to_csv('test_clen.csv')
