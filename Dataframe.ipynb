# %% [markdown]
# <a href="https://colab.research.google.com/github/nanutnutna/data_practice/blob/master/Dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install pymysql;
# Out:
# ...
#      |████████████████████████████████| 51kB 1.7MB/s
# ...

# %%
mysql_host = 'db4free.net'
mysql_port = 3306
mysql_user = 
mysql_pass = 
mysql_db = 
mysql_charset = 'utf8mb4'

# %%
import pymysql.cursors

connection = pymysql.connect(host= mysql_host,
                             port = mysql_port,
                             user = mysql_user,
                             password = mysql_pass,
                             db = mysql_db,
                             charset = mysql_charset,
                             cursorclass = pymysql.cursors.DictCursor)

# %%
cursor = connection.cursor()
cursor.execute("show tables;")
tables = cursor.fetchall()
cursor.close()
print(tables)
# Out:
# [{'Tables_in_data_4_practice': 'covid_19_2020_04_20'}]

# %%
with connection.cursor() as cursor:
  sql = 'select * from covid_19_2020_04_20'
  cursor.execute(sql)
  result = cursor.fetchall()

print(result)
# Out:
# [{'Date': '01/02/2020', 'NewConfirmed': 0, 'NewRecovered': 0, 'NewHospitalized': 0, 'NewDeaths': 0, 'Confirmed': 0, 'Recovered': 0, 'Hospitalized': 0, 'Deaths': 0}, {'Date': '01/03/2020', 'NewConfirmed': 0, 'NewRecovered': 0, 'NewHospitalized': 0, 'NewDeaths': 0, 'Confirmed': 0, 'Recovered': 0, 'Hospitalized': 0, 'Deaths': 0}, {'Date': '01/04/2020', 'NewConfirmed': 0, 'NewRecovered': 0, 'NewHospitalized': 0, 'NewDeaths': 0, 'Confirmed': 0, 'Recovered': 0, 'Hospitalized': 0, 'Deaths': 0}, {'Date': '01/05/2020', 'NewConfirmed': 0, 'NewRecovered': 0, 'NewHospitalized': 0, 'NewDeaths': 0, 'Confirmed': 0, 'Recovered': 0, 'Hospitalized': 0, 'Deaths': 0}, {'Date': '01/06/2020', 'NewConfirmed': 0, 'NewRecovered': 0, 'NewHospitalized': 0, 'NewDeaths': 0, 'Confirmed': 0, 'Recovered': 0, 'Hospitalized': 0, 'Deaths': 0}, {'Date': '01/07/2020', 'NewConfirmed': 0, 'NewRecovered': 0, 'NewHospitalized': 0, 'NewDeaths': 0, 'Confirmed': 0, 'Recovered': 0, 'Hospitalized': 0, 'Deaths': 0}, {'Date': '01/
# ...

# %%
import pandas as pd

# %%
show_table = pd.DataFrame(result)

# %%
show_table
# Out:
#            Date  NewConfirmed  NewRecovered  ...  Recovered  Hospitalized  Deaths
# 0    01/02/2020             0             0  ...          0             0       0
# 1    01/03/2020             0             0  ...          0             0       0
# 2    01/04/2020             0             0  ...          0             0       0
# 3    01/05/2020             0             0  ...          0             0       0
# 4    01/06/2020             0             0  ...          0             0       0
# ..          ...           ...           ...  ...        ...           ...     ...
# 105  04/16/2020            29            96  ...       1593          1033      46
# 106  04/17/2020            28            96  ...       1689           964      47
# 107  04/18/2020            33            98  ...       1787           899      47
# 108  04/19/2020            32           141  ...       1928           790      47
# ...

# %%
data = show_table['Date']
confirm = show_table['Confirmed']
death = show_table['Deaths']
recover = show_table['Recovered']

# %%
import matplotlib.pyplot as plt

# %%
confirm = plt.plot(data,confirm)
death = plt.plot(data,death)
recover = plt.plot(data,recover)

plt.show()

# %%
import requests

# %%
url = "https://covid19.th-stat.com/api/open/timeline"
req = requests.get(url)

# %%
type(req.text)
# Out:
# str

# %%
import json

# %%
result_convert = req.json()
result_convert
# Out:
# {'Data': [{'Confirmed': 0,
#    'Date': '01/01/2020',
#    'Deaths': 0,
#    'Hospitalized': 0,
#    'NewConfirmed': 0,
#    'NewDeaths': 0,
#    'NewHospitalized': 0,
#    'NewRecovered': 0,
#    'Recovered': 0},
#   {'Confirmed': 0,
#    'Date': '01/02/2020',
#    'Deaths': 0,
#    'Hospitalized': 0,
#    'NewConfirmed': 0,
#    'NewDeaths': 0,
#    'NewHospitalized': 0,
#    'NewRecovered': 0,
#    'Recovered': 0},
#   {'Confirmed': 0,
#    'Date': '01/03/2020',
#    'Deaths': 0,
#    'Hospitalized': 0,
#    'NewConfirmed': 0,
#    'NewDeaths': 0,
#    'NewHospitalized': 0,
#    'NewRecovered': 0,
#    'Recovered': 0},
#   {'Confirmed': 0,
#    'Date': '01/04/2020',
#    'Deaths': 0,
#    'Hospitalized': 0,
#    'NewConfirmed': 0,
#    'NewDeaths': 0,
#    'NewHospitalized': 0,
#    'NewRecovered': 0,
#    'Recovered': 0},
#   {'Confirmed': 0,
#    'Date': '01/05/2020',
#    'Deaths': 0,
#    'Hospitalized': 0,
#    'NewConfirmed': 0,
#    'NewDeaths': 0,
# ...

# %%
#covert_pandas = pd.DataFrame.from_dict(result_convert)

# %%
covert_pandas = pd.DataFrame.from_dict(result_convert['Data'])
covert_pandas
# Out:
#            Date  NewConfirmed  NewRecovered  ...  Recovered  Hospitalized  Deaths
# 0    01/01/2020             0             0  ...          0             0       0
# 1    01/02/2020             0             0  ...          0             0       0
# 2    01/03/2020             0             0  ...          0             0       0
# 3    01/04/2020             0             0  ...          0             0       0
# 4    01/05/2020             0             0  ...          0             0       0
# ..          ...           ...           ...  ...        ...           ...     ...
# 113  04/23/2020            13            78  ...       2430           359      50
# 114  04/24/2020            15            60  ...       2490           314      50
# 115  04/25/2020            53            57  ...       2547           309      51
# 116  04/26/2020            15            47  ...       2594           277      51
# ...

# %%
# วันที่ 25 เม.ย
comfrim = covert_pandas['Confirmed']
recover = covert_pandas['Recovered']
date = covert_pandas['Date']
hospitalized = covert_pandas['Hospitalized']

plt.plot(date,comfrim)
plt.plot(date,recover)
plt.plot(date,hospitalized)

# %%
a = covert_pandas['Confirmed']
b = covert_pandas['Recovered']
c = covert_pandas['Date']
plt.plot(c,a-b)
plt.plot(c,a)
