# %% [markdown]
# <a href="https://colab.research.google.com/github/nanutnutna/data_practice/blob/master/data_p1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# First project try to clear data

# %%
# เพื่อจะใช้ดึงข้อมูลมาจากลิ้งค์
import requests

# %%
url = 'https://covid19.th-stat.com/api/open/cases'
use  = requests.get(url)

# %%
convert_json = use.json()
type(convert_json)
# Out:
# dict

# %%
convert_json
# Out:
# {'Data': [{'Age': 39,
#    'ConfirmDate': '2020-04-29 00:00:00',
#    'Detail': None,
#    'District': '',
#    'Gender': 'ชาย',
#    'GenderEn': 'Male',
#    'Nation': 'ไทย',
#    'NationEn': 'Thai',
#    'No': '2944',
#    'Province': 'กรุงเทพมหานคร',
#    'ProvinceEn': 'Bangkok',
#    'ProvinceId': 1},
#   {'Age': 57,
#    'ConfirmDate': '2020-04-29 00:00:00',
#    'Detail': None,
#    'District': 'คลองสาน',
#    'Gender': 'หญิง',
#    'GenderEn': 'Female',
#    'Nation': 'ไทย',
#    'NationEn': 'Thai',
#    'No': '2943',
#    'Province': 'กรุงเทพมหานคร',
#    'ProvinceEn': 'Bangkok',
#    'ProvinceId': 1},
#   {'Age': 8,
#    'ConfirmDate': '2020-04-29 00:00:00',
#    'Detail': None,
#    'District': 'เมือง',
#    'Gender': 'หญิง',
#    'GenderEn': 'Female',
#    'Nation': 'ไทย',
#    'NationEn': 'Thai',
#    'No': '2939',
#    'Province': 'กรุงเทพมหานคร',
#    'ProvinceEn': 'Bangkok',
#    'ProvinceId': 1},
#   {'Age': 22,
#    'ConfirmDate': '2020-04-29 00:00:00',
# ...
